# %% [markdown]
# <a href="https://colab.research.google.com/github/alagiehafigue/ai-ml-engineering/blob/main/model_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score
df = pd.read_csv('predictions.csv');
df.shape
df.head()
# Out:
#   truth predicted
# 0   ham       ham
# 1   ham       ham
# 2   ham       ham
# 3  spam      spam
# 4   ham       ham

# %%
x_truth = df['truth']
y_pred = df['predicted']

confusion_matrix(x_truth, y_pred)
# Out:
# array([[41,  1],
#        [ 6,  2]])
